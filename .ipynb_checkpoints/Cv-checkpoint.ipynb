# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np
# %maqtplotlib inline
# Out:
# UsageError: Line magic function `%maqtplotlib` not found.

# %%
image=mpimg.imread('kol.jpg')

# %%
plt.imshow(image)

# %%
image
# Out:
# array([[[  0, 190, 255],
#         [  0, 190, 255],
#         [  0, 190, 255],
#         ...,
#         [224, 160, 114],
#         [222, 158, 112],
#         [221, 157, 111]],
#
#        [[  0, 189, 255],
#         [  0, 190, 255],
#         [  0, 189, 255],
#         ...,
#         [224, 160, 114],
#         [222, 158, 112],
#         [222, 158, 112]],
#
#        [[  2, 190, 254],
#         [  1, 190, 254],
#         [  2, 190, 254],
#         ...,
#         [224, 160, 114],
#         [223, 159, 113],
#         [222, 158, 112]],
#
#        ...,
#
#        [[150,  86,  50],
#         [160,  96,  58],
#         [162,  98,  60],
#         ...,
#         [225, 193, 136],
#         [226, 194, 137],
#         [227, 195, 138]],
#
#        [[166, 102,  56],
#         [174, 112,  65],
#         [177, 115,  66],
#         ...,
#         [224, 192, 135],
#         [225, 193, 136],
#         [225, 193, 136]],
#
#        [[180, 115,  59],
#         [187, 125,  68],
#         [190, 128,  71],
#         ...,
#         [222, 190, 133],
#         [222, 190, 133],
#         [222, 190, 133]]], dtype=uint8)

# %%
r=image[:,:,0]
g=image[:,:,1]
b=image[:,:,2]
f,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(20,10))
ax1.set_title("R Channel")
ax1.imshow(r,cmap='gray')
ax2.set_title("g Channel")
ax2.imshow(g,cmap='gray')
ax3.set_title("b Channel")
ax3.imshow(r,cmap='gray')

# %%
r=image[:,:,0]
g=image[:,:,1]
b=image[:,:,2]
f,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(20,10))
ax1.set_title("R Channel")
ax1.imshow(r)
ax2.set_title("g Channel")
ax2.imshow(g)
ax3.set_title("b Channel")
ax3.imshow(r)

# %%
gray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
gray
# Out:
# array([[141, 141, 141, ..., 174, 172, 171],
#        [140, 141, 140, ..., 174, 172, 172],
#        [141, 141, 141, ..., 174, 173, 172],
#        ...,
#        [101, 111, 113, ..., 196, 197, 198],
#        [116, 125, 128, ..., 195, 196, 196],
#        [128, 137, 140, ..., 193, 193, 193]], dtype=uint8)

# %%
gray.shape
# Out:
# (667, 1000)

# %%
plt.imshow(gray,cmap='gray')

# %%
plt.imshow(gray)
